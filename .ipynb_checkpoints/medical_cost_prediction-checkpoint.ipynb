# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDRegressor
import time
import pickle

# %% [markdown]
# # Data collection / Gathering

# %%
data=pd.read_csv('insurance.csv')

# %% [markdown]
# # Understanding the data

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.corr(numeric_only=True)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %% [markdown]
#  # Exploratory Data Analysis (EDA)- Univariate Analysis

# %% [raw]
# 1> Categorical data:-

# %%
plt.figure(figsize=(25,10))

plt.subplot(1,2,1)
sns.countplot(x='region', data=data)    

plt.subplot(1,2,2)
sns.countplot(x='smoker', data=data)
plt.savefig('C:\\Users\\DELL\\Medical Price prediction\\region_smoker_plot.png')

plt.show()

# %%
data['sex'].value_counts().plot(kind='pie', autopct='%.2f%%')
plt.savefig('C:\\Users\\DELL\\Medical Price prediction\\sex_plot.png')
plt.show()

# %% [raw]
# 2> Numerical data:-

# %%
plt.hist(data['age'],bins=[10,20,30,40,50,60,70])
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(1, 3, 1)
sns.boxplot(y=data['age'])
plt.title('Age')

plt.subplot(1, 3, 2)
sns.boxplot(y=data['bmi'])
plt.title('BMI')

plt.subplot(1, 3, 3)
sns.boxplot(y=data['charges'])
plt.title('Charges')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(data['bmi'])

plt.subplot(1,2,2)
sns.distplot(data['charges'])

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15196\703496756.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['bmi'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15196\703496756.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['charges'])

# %% [markdown]
#  # Exploratory Data Analysis (EDA)- Bivariate Analysis and Multivariate analysis

# %%
sns.relplot(x=data['bmi'], y=data['charges'],hue=data['smoker'])
plt.show()

# %%
sns.barplot(x='children', y='age', data=data)
plt.show()

# %%
sns.heatmap(pd.crosstab(data['region'], data['smoker']), annot=True)
plt.show()

# %%
sns.pairplot(data, hue='smoker')
plt.savefig('C:\\Users\\DELL\\Medical Price prediction\\pairplot_plot.png')
plt.show()

# %% [markdown]
# # Data cleaning

# %%
data.drop_duplicates(inplace=True)

# %%
sns.distplot(data['bmi'])

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15196\4235751418.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['bmi'])

# %%
data['bmi'].skew()
# Out:
# 0.28391419385321137

# %%
# z-score
upper_limit=data['bmi'].mean()+3*data['bmi'].std()
lower_limit=data['bmi'].mean()-3*data['bmi'].std()

# capping
data['bmi']=np.where(
    data['bmi']>upper_limit,
    upper_limit,
    np.where(
        data['bmi']<lower_limit,
        lower_limit,
        data['bmi']
    )
)

# %% [markdown]
# # Train_test_Split

# %%
x_train,x_test,y_train,y_test=train_test_split(data.drop('charges',axis=1),data['charges'],test_size=0.2)
x_train
# Out:
#       age     sex     bmi  children smoker     region
# 901    60    male  40.920         0    yes  southeast
# 594    41    male  40.260         0     no  southeast
# 681    19    male  20.300         0     no  southwest
# 1231   20  female  21.800         0    yes  southwest
# 431    29  female  20.235         2     no  northwest
# ...   ...     ...     ...       ...    ...        ...
# 569    48    male  40.565         2    yes  northwest
# 665    43    male  38.060         2    yes  southeast
# 1157   23  female  23.180         2     no  northwest
# 662    32  female  31.540         1     no  northeast
# 233    59    male  27.500         1     no  southwest
#
# [1069 rows x 6 columns]

# %% [markdown]
# # Feature Engineering

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.histplot(data['bmi'],kde=True)
plt.title('bmi distribution')
plt.subplot(122)
stats.probplot(data['bmi'], dist="norm", plot=plt)
plt.title('bmi qq plot')
plt.savefig('C:\\Users\\DELL\\Medical Price prediction\\pa_plot.png')
plt.show()

# %%
numeric_features = ['age','bmi','children']
categorical_features = ['sex','smoker','region']

# %%
preprocess = ColumnTransformer([
    ('log_bmi', FunctionTransformer(np.log1p), ['bmi']),
    ('num', StandardScaler(), numeric_features),
    ('cat', OneHotEncoder(drop='first'), categorical_features)
], remainder='passthrough')

# %% [markdown]
# # Pipeline

# %%
pipe = Pipeline([
    ('preprocess', preprocess),
    ('model', SGDRegressor( learning_rate='constant',eta0=0.003,max_iter=2500,penalty=None))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('log_bmi',
#                                                   FunctionTransformer(func=<ufunc 'log1p'>),
#                                                   ['bmi']),
#                                                  ('num', StandardScaler(),
#                                                   ['age', 'bmi', 'children']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['sex', 'smoker',
#                                                    'region'])])),
#                 ('model',
#                  SGDRegressor(eta0=0.003, learning_rate='constant',
#                               max_iter=2500, penalty=None))])

# %%
start=time.time()
pipe.fit(x_train,y_train)
print("time taken is:",time.time()-start)
# Out:
# time taken is: 0.012240171432495117

# %%
y_predict=pipe.predict(x_test)

# %%
y_predict
# Out:
# array([38930.05447546,  4787.34124634, 11256.07432712,  7757.41165756,
#        13057.84206454, 27489.11767823,  6460.71503318, 13400.47339522,
#        39579.87645495, 11710.20550746,  3117.93295628, 28077.12306538,
#         4078.33369761,  6483.31340843, 34137.84511281, 32767.41732271,
#        30988.04128491,  7264.47874661,  4536.81138768, 11361.83638612,
#         6512.01885519, 11753.81896682, 11562.60715323, 13751.72351482,
#        11452.26718801, 34797.75101426,  5135.5542846 , 14050.68840408,
#        15262.10041868, 12052.9584304 , 31322.84226973,  8675.75948795,
#         2871.58067308, 11847.48939473,  5084.63903634, 25327.23944782,
#         7131.19977956, 14811.55595814, 26566.26708839, 14761.13535185,
#        15383.22185791,  4557.8383815 ,  5511.95988903, 35444.43537759,
#         4274.34195839, 37171.90877563, 10917.34835661,   618.37120755,
#          999.96044341, 12475.02528018,  6358.17121665,  9297.50765349,
#         3458.7881481 , 35158.60225769,  7836.39693107, 12442.93527748,
#         6071.44308326, 32406.53218418, 38256.24245287, 13736.17589076,
#        11023.95592971, 16930.22660539,  5474.27406778, 13620.39625337,
#        38862.80577324, 27838.47359809, 35403.67090551,  2601.20554924,
#        30024.56781508,  8102.6923244 ,  8095.66969963, 14971.84748011,
#        10406.68505332, 15373.37582542,  9439.12449304, 15174.76387298,
#         7535.56719282, 15354.73785527, 34004.77558676,  6519.44621457,
#        12295.95230052,  7449.37407656,  8384.86508781,  7289.9072598 ,
#        11616.73367745, 10206.77981936, 16385.2222939 , 32295.45328957,
#         7808.37654559, 10390.62238752, 16350.29683284, 39802.8901064 ,
#         3387.23251921,  3965.73366579, 14067.55435602,  2188.7137837 ,
#         9904.71509249, 13340.15379208,  4787.53546326,  3447.55772014,
#         4354.33981018,  4029.98609609,  5145.70315257,  1105.17539928,
#        11835.11193181, 11698.42711989, 35704.42005907, 11514.85561604,
#         2571.52752691, 27954.64548155, 16753.38758704,  8828.71964131,
#         -843.80527436, 11733.22772493,  7671.15278694, 10602.45361063,
#         7161.50471192, 16847.38428055, 31308.36808258, 14888.10866105,
#        12610.42546637,  9453.02675713, 40561.12293831,  2199.01761626,
#        12396.29466185,  9763.9774635 , 27955.13635965,  5512.10090832,
#         4407.05091486, 10654.22150769,  5743.42119674, 13731.25280806,
#        11769.07450493,  5560.21889352, 37260.98236866,  9300.70069399,
#        11830.11622992, 25631.65737696, 10550.2949349 ,  4659.25965838,
#        33048.18032021,  5737.89838259, 15694.26391949,  4494.12029267,
#         8191.61905726, 15837.03065828, 39640.10790377,  9919.42860879,
#         5060.74778577,   615.99491032,  5047.4288295 , 18577.04717887,
#         8845.1382409 ,  9149.5527385 , 10278.68976733,  5994.2209444 ,
#         8651.72234057,  9215.30620096,  8630.29130176, 10832.56032348,
#         4573.10188391, 15216.03958322,  3897.54400438,  6378.66900822,
#        12590.96482245, 10517.41903094, 10554.76574555, 26423.21758962,
#         9856.25342745, 16694.94816573,  4757.18535221,   725.41297857,
#        14570.33579527, 33804.66818786, 11100.40762973, 15505.3334809 ,
#         7422.19874356, 11983.1597037 ,  1558.43900799,  8431.22622166,
#        39305.7036113 ,  8877.40575922, 15626.21940323, 12058.42537792,
#         9011.82587294, 13536.32841917,  3619.51773572, 31470.27749015,
#        14081.94203506,  2444.54794013,  6197.71262954,  7051.70145213,
#         -204.11989435, 27669.69573734,  4525.99325058,  2913.77180691,
#        11431.33066075,   -88.07668455,  8018.54748265, 14367.44880999,
#         6424.22227616, 40033.97879174,  1596.33041801,  3206.98705424,
#         7366.53599655, 28812.95816168, 34948.41368792,  5847.30009486,
#        40111.67710753,  7278.37882827, 17058.22056473, 10096.13348937,
#         5647.30094754, 25227.35350556, 16849.46107573,  1401.69793358,
#         5094.26048993,  4259.20792766, 25377.29473054, 11550.25000546,
#         8195.83478718,  4692.69939739, 14258.68060153, 12960.45886383,
#         7853.31731504, 10720.36098947, 16159.70184286, 13766.1581256 ,
#        36019.45399387,  9944.61628837, 10439.08610202,  5792.52562895,
#        30663.08144904,  6352.44851204,  5630.86386331,  7219.01828658,
#        11716.49593544,  9016.00383226,  8760.29985323, 11917.31956414,
#         7255.70020361, 36716.0538147 ,  6525.4963454 , 15889.2266493 ,
#        29223.63332267,  4726.66510349,  4607.84860158, 27455.2513576 ,
#        41070.17128489,  4605.76885453, 16378.15123393, 11322.46579222,
#        25837.60709383,  8373.1185993 , 26890.41985324, 14458.04883684,
#         3265.4922035 , 11453.8161189 , 10499.15452665, 10850.14508212,
#         1746.80518784, 14932.15947439, 10052.80561543,  8181.91536288,
#        17639.09201252,  9532.58743282,  8336.80620242,  6303.37076052])

# %%
y_test
# Out:
# 92      30184.93670
# 101      3645.08940
# 372      7639.41745
# 189      4922.91590
# 62      30166.61817
#            ...
# 1261     3277.16100
# 867     11576.13000
# 1074    13204.28565
# 967      7518.02535
# 434      4243.59005
# Name: charges, Length: 268, dtype: float64

# %%
print("R² Score:", r2_score(y_test,y_predict))
# Out:
# R² Score: 0.7351675074847973

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))
